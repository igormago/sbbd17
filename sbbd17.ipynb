# %% [markdown]
# # SBBD'17 - Minicurso: Sports Analytics - Mudando o Jogo
# **Atividade:** Prever os resultados dos jogos do Campeonato Brasileiro de 2016.
#
# **Datasets:**
# - Resultados dos últimos 11 anos de campeonato (2005-2016)
# - Performances dos times a cada rodada

# %%
#Importando algumas bibliotecas importantes
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Importando alguns classificadores 
from sklearn.naive_bayes import GaussianNB 
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier

# import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
# warnings.filterwarnings("ignore")

# %%
#Lendo Dataframe de um arquivo CSV
df = pd.read_csv('df_performances.csv')

# %%
#Quais colunas tem esse dataframe?
df.columns
# Out:
# Index(['c_id', 'c_name', 's_id', 's_path', 's_year', 's_type',
#        's_championship_id', 'm_id', 'm_season_id', 'm_team_home_id',
#        'm_team_away_id', 'm_goals_home', 'm_goals_away', 'm_column_result',
#        'm_match_date', 'm_round_num', 'm_odd_home', 'm_odd_draw', 'm_odd_away',
#        'm_match_num', 'm_match_group_num', 'm_observation', 'h_season_id',
#        'h_team_id', 'h_matches_played', 'h_local', 'h_last_matches_num',
#        'h_num_wins', 'h_num_draws', 'h_num_loses', 'h_num_goals_for',
#        'h_num_goals_against', 'h_num_goals_balance', 'h_num_points',
#        'h_num_bts_yes', 'h_num_bts_no', 'h_next_match_id', 'h_last_match_id',
#        'a_season_id', 'a_team_id', 'a_matches_played', 'a_local',
#        'a_last_matches_num', 'a_num_wins', 'a_num_draws', 'a_num_loses',
#        'a_num_goals_for', 'a_num_goals_against', 'a_num_goals_balance',
#        'a_num_points', 'a_num_bts_yes', 'a_num_bts_no', 'a_next_match_id',
# ...

# %%
#Olhando as primeiras linhas dos dados
df
# Out:
#       c_id      c_name  s_id          s_path  s_year  s_type  \
# 0        1  Brazil - A     1  brazil/serie-a    2006       1
# 1        1  Brazil - A     1  brazil/serie-a    2006       1
# 2        1  Brazil - A     1  brazil/serie-a    2006       1
# 3        1  Brazil - A     1  brazil/serie-a    2006       1
# 4        1  Brazil - A     1  brazil/serie-a    2006       1
# 5        1  Brazil - A     1  brazil/serie-a    2006       1
# 6        1  Brazil - A     1  brazil/serie-a    2006       1
# 7        1  Brazil - A     1  brazil/serie-a    2006       1
# 8        1  Brazil - A     1  brazil/serie-a    2006       1
# 9        1  Brazil - A     1  brazil/serie-a    2006       1
# 10       1  Brazil - A     1  brazil/serie-a    2006       1
# 11       1  Brazil - A     1  brazil/serie-a    2006       1
# 12       1  Brazil - A     1  brazil/serie-a    2006       1
# 13       1  Brazil - A     1  brazil/serie-a    2006       1
# ...

# %%
#Inicializando um classificador 
#Mais opções em: http://scikit-learn.org/stable/

clf = DecisionTreeClassifier()
clf = svm.SVC()
clf = GaussianNB()
clf = MLPClassifier()
clf = KNeighborsClassifier()
clf = RandomForestClassifier()
clf = GradientBoostingClassifier()

# %%
#df = df.fillna(0)

#Dividindo os Dados em Treino e Teste
train = df[(df.s_year < 2016)]
test = df[(df.s_year == 2016)]

#Selecionando algumas features para predição
features = ['h_num_wins','a_num_wins']

#Selecionando a variável alvo
target = 'm_column_result'

#Dividindo o conjunto de treinamento (features e alvo)
train_x = train[features]
train_y = train[target]

#Dividindo o conjunto de teste (features e alvo)
test_x = test[features]
test_y = test[target]

#Treinando o classificador
clf.fit(train_x,train_y)

#Verificando a acurácia do modelo treinado com o conjunto de teste
score = clf.score(test_x, test_y)

print(score)
# Out:
# 0.539473684211

# %%
hits = test[test[target] == test['predict']]
errors = test[test[target] != test['predict']]

print(len(hits))
print(len(errors))

print(hits['m_odd_home'].sum())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/igormago/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'predict'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
